# %%
from src.image_embeddings import generate_embeddings

# %% [markdown]
# ### Function usage

# %%
generate_embeddings(
    meta="data/meta_toys_games.json.gz",
    out="gnn_embeddings/embeddings_toys_checkpoint.parquet",
    imgdir="data/images",
    batch=64,
    device="cuda:0",
)

# %% [markdown]
# #### OBS: this may take a while, since the Toys and Games dataset will contain 211k nodes
